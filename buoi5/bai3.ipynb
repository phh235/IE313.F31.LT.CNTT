# %%
import pandas as pd

# %%
s = pd.Series(
    data=[2, 3, 4.5, 5, 3],
    index=['a', 'b', 'c', 'd', 'e']
)

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
s.plot(kind="box")
# Out:
# <Axes: >

# %%
df = pd.DataFrame(
    data={
        'a': [1, 2, 3, 4],
        'b': [5, 6, 7, 8],
        'c': [9, 10, 11, 12]
    }
)

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
df.set_index('a', inplace=True)

# %%
df['b'].plot()
# Out:
# <Axes: xlabel='a'>
